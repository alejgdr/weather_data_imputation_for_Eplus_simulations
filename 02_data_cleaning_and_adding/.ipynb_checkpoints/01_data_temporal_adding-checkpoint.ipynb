# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import clean_and_add as cld
#code imported from '../../aigz/02_Programs/02_Data_Preprocessing/Raw_preprocessing_ceros.ipynb'
# in case of an error in future notebooks

# %% [markdown]
# # Adding solar temporal values

# %%
# df=importa2('../../01_Documentos/01_Raw/Temixco_TMY.csv')
nombres=['tiempo','Direct','Global','Difusa','Temperatura','Humedad','Presion']
nombres2=['tiempo','Direct','Global','Difusa','Temperatura','Humedad','Viento','Presion','WDir_Avg','Rain_Tot']
archivo_tmy='../01_weather_data/01_raw_data/Temixco_TMY.csv'
archivo_val='../01_weather_data/01_raw_data/ESORUOA2019.csv'
tmy=pd.read_csv(archivo_tmy,names=nombres,index_col=0,parse_dates=True,skiprows=1)
tmx_2019=pd.read_csv(archivo_val,names=nombres2,index_col=0,parse_dates=True,skiprows=1)

# %%
tmy_night=cld.nightzero_timeprep(tmy,saved_file='TMY_night_solar_angles.csv',save=True,saving_path='../01_weather_data/02_cleaned_data/',)
tmx_2019_night=cld.nightzero_timeprep(tmx_2019,saved_file='esoru_night_angles.csv',save=True,saving_path='../01_weather_data/02_cleaned_data/')
tmy_night
# Out:
#                      Direct  Global  Difusa  Temperatura  Humedad   Presion  \
# tiempo
# 2015-01-01 00:00:00     0.0     0.0     0.0        17.75    60.12  878.4097
# 2015-01-01 00:10:00     0.0     0.0     0.0        17.46    59.51  878.8270
# 2015-01-01 00:20:00     0.0     0.0     0.0        17.78    57.60  878.8638
# 2015-01-01 00:30:00     0.0     0.0     0.0        18.08    59.78  878.7399
# 2015-01-01 00:40:00     0.0     0.0     0.0        17.57    59.99  878.6697
# ...                     ...     ...     ...          ...      ...       ...
# 2014-12-31 23:10:00     0.0     0.0     0.0        18.41    58.97  878.8984
# 2014-12-31 23:20:00     0.0     0.0     0.0        19.02    56.31  878.8088
# 2014-12-31 23:30:00     0.0     0.0     0.0        18.66    56.72  878.6418
# 2014-12-31 23:40:00     0.0     0.0     0.0        18.48    56.44  878.4005
# 2014-12-31 23:50:00     0.0     0.0     0.0        18.32    58.76  878.3346
#
#                      alturasolar     azimuth
# tiempo
# 2015-01-01 00:00:00   -79.806160  166.773196
# 2015-01-01 00:10:00   -81.878940  170.053742
# 2015-01-01 00:20:00   -83.764991  173.367191
# 2015-01-01 00:30:00   -85.236372  176.703016
# 2015-01-01 00:40:00   -85.827949 -179.949903
# ...                          ...         ...
# 2014-12-31 23:10:00   -68.725457  151.345160
# 2014-12-31 23:20:00   -71.001501  154.338568
# 2014-12-31 23:30:00   -73.264218  157.400817
# 2014-12-31 23:40:00   -75.506650  160.527038
# 2014-12-31 23:50:00   -77.716959  163.711070
#
# [51570 rows x 8 columns]

# %%
tmx_2019
# Out:
#                      Direct  Global  Difusa  Temperatura  Humedad  Viento  \
# tiempo
# 2019-01-01 00:00:00     0.0     0.0     0.0        17.85    59.02   0.723
# 2019-01-01 00:10:00     0.0     0.0     0.0        18.29    59.84   1.385
# 2019-01-01 00:20:00     0.0     0.0     0.0        17.92    60.08   0.057
# 2019-01-01 00:30:00     0.0     0.0     0.0        17.91    61.51   0.003
# 2019-01-01 00:40:00     0.0     0.0     0.0        17.94    61.41   0.467
# ...                     ...     ...     ...          ...      ...     ...
# 2019-12-31 23:10:00     0.0     0.0     0.0        20.94    58.99   1.740
# 2019-12-31 23:20:00     0.0     0.0     0.0        21.20    58.03   0.189
# 2019-12-31 23:30:00     0.0     0.0     0.0        21.52    56.33   0.043
# 2019-12-31 23:40:00     0.0     0.0     0.0        21.67    57.35   0.090
# 2019-12-31 23:50:00     0.0     0.0     0.0        21.31    58.82   0.574
#
#                       Presion  WDir_Avg  Rain_Tot  diajuliano  minutodia  \
# tiempo
# 2019-01-01 00:00:00  875.2408  283.3897       0.0           1          0
# 2019-01-01 00:10:00  875.1749   90.5656       0.0           1         10
# 2019-01-01 00:20:00  874.8231  151.5240       0.0           1         20
# 2019-01-01 00:30:00  874.7002  287.5600       0.0           1         30
# 2019-01-01 00:40:00  874.6029  308.7000       0.0           1         40
# ...                       ...       ...       ...         ...        ...
# 2019-12-31 23:10:00  877.1380  121.3200       0.0         365       1390
# 2019-12-31 23:20:00  876.9656  200.2775       0.0         365       1400
# 2019-12-31 23:30:00  876.6717  132.4180       0.0         365       1410
# 2019-12-31 23:40:00  877.0899  321.0300       0.0         365       1420
# 2019-12-31 23:50:00  877.0317  297.0700       0.0         365       1430
#
#                      alturasolar        Cs        Ss     azimuth  prediccion
# tiempo
# 2019-01-01 00:00:00   -79.806160 -3.828089  0.899760  166.773196         0.0
# 2019-01-01 00:10:00   -81.878940 -4.825720  0.846238  170.053742         0.0
# 2019-01-01 00:20:00   -83.764991 -6.304553  0.733120  173.367191         0.0
# 2019-01-01 00:30:00   -85.236372 -8.266807  0.476224  176.703016         0.0
# 2019-01-01 00:40:00   -85.827949 -9.444560 -0.008258 -179.949903         0.0
# ...                          ...       ...       ...         ...         ...
# 2019-12-31 23:10:00   -68.725457 -1.764251  0.964093  151.345160         0.0
# 2019-12-31 23:20:00   -71.001501 -1.997164  0.959515  154.338568         0.0
# 2019-12-31 23:30:00   -73.264218 -2.288691  0.952652  157.400817         0.0
# 2019-12-31 23:40:00   -75.506650 -2.664239  0.942042  160.527038         0.0
# 2019-12-31 23:50:00   -77.716959 -3.164985  0.924843  163.711070         0.0
#
# [52560 rows x 16 columns]

# %%
fecha1='2019-06'
fig, ax= plt.subplots(figsize=(20,10))
ax.plot(tmx_2019_night.loc[fecha1].azimuth,'b.')
ax.plot(tmx_2019_night.loc[fecha1].alturasolar,'r.')

# %%
fecha='2019-12-31'
fig, ax=plt.subplots(figsize=(20,10))
ax.plot(tmx_2019.loc[fecha].Direct,'k-')
ax.plot(tmx_2019_night.loc[fecha].Direct,'g-')
# ax.plot(tmxnoche[fecha].Difusa,'y-')
ax.set_ylim(0,10)
# Out:
# (0.0, 10.0)
