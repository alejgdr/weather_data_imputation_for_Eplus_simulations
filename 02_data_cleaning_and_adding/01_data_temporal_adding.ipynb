# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import clean_and_add as cld
#code imported from '../../aigz/02_Programs/02_Data_Preprocessing/Raw_preprocessing_ceros.ipynb'
# in case of an error in future notebooks

# %% [markdown]
# # Adding solar temporal values

# %%
# df=importa2('../../01_Documentos/01_Raw/Temixco_TMY.csv')
nombres=['tiempo','Direct','Global','Difusa','Temperatura','Humedad','Presion']
nombres2=['tiempo','Direct','Global','Difusa','Temperatura','Humedad','Viento','Presion','WDir_Avg','Rain_Tot']
archivo_tmy='../01_weather_data/01_raw_data/Temixco_TMY.csv'
archivo_val='../01_weather_data/01_raw_data/ESORUOA2019.csv'
tmy=pd.read_csv(archivo_tmy,names=nombres,index_col=0,parse_dates=True,skiprows=1)
tmx_2019=pd.read_csv(archivo_val,names=nombres2,index_col=0,parse_dates=True,skiprows=1)

# %%
tmy_night=cld.nightzero_timeprep(tmy,saved_file='TMY_night_solar_angles.csv',save=True,saving_path='../01_weather_data/02_cleaned_data/',)
tmx_2019_night=cld.nightzero_timeprep(tmx_2019,saved_file='esoru_night_angles.csv',save=True,saving_path='../01_weather_data/02_cleaned_data/')
tmy_night

# %%
tmx_2019
# Out:
#                      Direct  Global  Difusa  Temperatura  Humedad  Viento  \
# tiempo
# 2019-01-01 00:00:00   0.028     0.0     0.0        17.85    59.02   0.723
# 2019-01-01 00:10:00   0.182     0.0     0.0        18.29    59.84   1.385
# 2019-01-01 00:20:00   0.000     0.0     0.0        17.92    60.08   0.057
# 2019-01-01 00:30:00   0.066     0.0     0.0        17.91    61.51   0.003
# 2019-01-01 00:40:00   0.069     0.0     0.0        17.94    61.41   0.467
# ...                     ...     ...     ...          ...      ...     ...
# 2019-12-31 23:10:00   0.029     0.0     0.0        20.94    58.99   1.740
# 2019-12-31 23:20:00   0.014     0.0     0.0        21.20    58.03   0.189
# 2019-12-31 23:30:00   0.222     0.0     0.0        21.52    56.33   0.043
# 2019-12-31 23:40:00   0.115     0.0     0.0        21.67    57.35   0.090
# 2019-12-31 23:50:00   0.130     0.0     0.0        21.31    58.82   0.574
#
#                       Presion  WDir_Avg  Rain_Tot
# tiempo
# 2019-01-01 00:00:00  875.2408  283.3897       0.0
# 2019-01-01 00:10:00  875.1749   90.5656       0.0
# 2019-01-01 00:20:00  874.8231  151.5240       0.0
# 2019-01-01 00:30:00  874.7002  287.5600       0.0
# 2019-01-01 00:40:00  874.6029  308.7000       0.0
# ...                       ...       ...       ...
# 2019-12-31 23:10:00  877.1380  121.3200       0.0
# 2019-12-31 23:20:00  876.9656  200.2775       0.0
# 2019-12-31 23:30:00  876.6717  132.4180       0.0
# 2019-12-31 23:40:00  877.0899  321.0300       0.0
# 2019-12-31 23:50:00  877.0317  297.0700       0.0
#
# [52560 rows x 9 columns]

# %%
fecha1='2019-06'
fig, ax= plt.subplots(figsize=(20,10))
ax.plot(tmx_2019.loc[fecha1].azimuth,'b.')
ax.plot(tmx_2019_night.loc[fecha1].alturasolar,'r.')

# %% [markdown]
# # Corregir ceros de la noche

# %%
fecha='2014-12-31'
fig, ax=plt.subplots(figsize=(20,10))
ax.plot(tmxnoche[fecha].Global,'k-')
ax.plot(tmxnoche[fecha].Direct,'g-')
ax.plot(tmxnoche[fecha].Difusa,'y-')
ax.set_ylim(0,10)
# Out:
# <ipython-input-59-daa1b5b413a2>:3: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   ax.plot(tmxnoche[fecha].Global,'k-')
# <ipython-input-59-daa1b5b413a2>:4: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   ax.plot(tmxnoche[fecha].Direct,'g-')
# <ipython-input-59-daa1b5b413a2>:5: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   ax.plot(tmxnoche[fecha].Difusa,'y-')
# (0.0, 10.0)
