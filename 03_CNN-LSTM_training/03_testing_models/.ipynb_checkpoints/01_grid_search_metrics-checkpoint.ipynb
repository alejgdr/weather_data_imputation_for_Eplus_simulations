# %%
import testing as tst
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pickle import load, dump 
import math
import datetime

# %% [markdown]
# # Import data, model, scalers, in_size

# %%
nombres1=['tiempo','Direct','Global','Difusa','Temperatura','Humedad','Presion','alturasolar','azimuth']
esoru=tst.importa('../../01_weather_data/02_cleaned_data/esoru_night_angles.csv',nombres1)

# %%
esoru.loc['2019-09-30']=esoru.loc['2019-09-29']

# %%
esoru.isna().sum()
# Out:
# Direct         160
# Global         160
# Difusa         160
# Temperatura    189
# Humedad        189
# Presion        189
# alturasolar    144
# azimuth        144
# dtype: int64

# %%
# tmy=tst.importa('../../01_weather_data/02_cleaned_data/TMY_night_solar_angles.csv',nombres1)
dias_rango=363
forward_steps=dias_rango*144
in_size,out_size= 6,6 
istep=0
model_name='../02_grid_training/01_models/01_models/train_seasonal_layers_3_3_1_out_s_6in_s_6_lr_0.0001_Global_BS24.h5'
model=tst.load_model(model_name)
inputs=['Global','Direct','Temperatura','Humedad','azimuth','alturasolar']
outputs=['Global']
training_step=1
season_size=144
scalery=load(open('../02_grid_training/03_scalers/y_scalerv01.pkl','rb'))
scalerx=load(open('../02_grid_training/03_scalers/x_scalerv01.pkl','rb'))
# rango=out_size*int((dias_rango*144)/out_size)


predi,targ=tst.Multioneshot(esoru,forward_steps,out_size,in_size,istep,model,inputs,outputs,training_step,season_size,scalerx,scalery)
# (esoru,rango,out_size,in_size,istep,model5,inputs,scaler2=scaler3,scaler=scaler4)
# Out:
#                      Global  Direct  Temperatura  Humedad     azimuth  \
# tiempo
# 2019-01-01 00:00:00     0.0     0.0        17.85    59.02  166.773196
# 2019-01-01 00:10:00     0.0     0.0        18.29    59.84  170.053742
# 2019-01-01 00:20:00     0.0     0.0        17.92    60.08  173.367191
# 2019-01-01 00:30:00     0.0     0.0        17.91    61.51  176.703016
# 2019-01-01 00:40:00     0.0     0.0        17.94    61.41 -179.949903
# ...                     ...     ...          ...      ...         ...
# 2019-12-31 23:10:00     0.0     0.0        20.94    58.99  151.345160
# 2019-12-31 23:20:00     0.0     0.0        21.20    58.03  154.338568
# 2019-12-31 23:30:00     0.0     0.0        21.52    56.33  157.400817
# 2019-12-31 23:40:00     0.0     0.0        21.67    57.35  160.527038
# 2019-12-31 23:50:00     0.0     0.0        21.31    58.82  163.711070
#
#                      alturasolar
# tiempo
# 2019-01-01 00:00:00   -79.806160
# 2019-01-01 00:10:00   -81.878940
# ...

# %% [markdown]
# # Importo datos para sustituir datos predecidos

# %% [markdown]
# ## Sustituyo datos predecidos

# %% [markdown]
# ### y confirmo que predi es lo mismo a los datos que sustituí

# %% [markdown]
# ## Le agrego el index de fechas

# %%
impesoru=tst.seasonal_exporta('../../01_weather_data/02_cleaned_data/esoru_night_angles.csv',predi,istep,in_size,forward_steps,season_size,nombres1,sol_data_correction=True)
#                                                                                             (archivo,predi,istep,in_size,rango,season_size,nombres,sol_data_correction=False,save=False,archivo_nombre='imputados_corregidos.csv')
impesoru_target=pd.read_csv('../../01_weather_data/02_cleaned_data/esoru_night_angles.csv',names=nombres1,index_col=0,parse_dates=True,skiprows=1)
# Out:
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
rango=forward_steps
impesoru.Global[istep:istep+rango].plot(figsize=(20,10),alpha=1,label='prediccion')
impesoru_target.Global[istep:istep+rango].plot(alpha=.8,label='real')
plt.legend()

# %% [markdown]
# # MAE

# %%
dfrad=impesoru_target.copy()
dfrad['prediccion']=impesoru.Global.copy().astype(float)
dfrad['minutodia']=(dfrad.index.hour*60)+dfrad.index.minute
dfrad['me']=(dfrad.prediccion-dfrad.Global).astype(float)
dfrad['mae']=np.abs(dfrad.Global-dfrad.prediccion).astype(float)

# %%
fig, ax=plt.subplots(figsize=(20,10))
fecha='2019-10-20'
fecha2='2019-10-25'
ax.plot(dfrad.prediccion[fecha:fecha2],'r.-',label='predicción [W/m2]')
#ax2=ax.twinx()
# ax.plot(dfrad.alturasolar[fecha],'y.')
ax.plot(dfrad.Global[fecha:fecha2],label='Real')
#ax.plot(dfrad.Global[fecha2],label='Real')
ax.plot(dfrad.mae[fecha:fecha2],label='mae [W/m2]')
# ax.plot(dfrad.me[fecha],label='me')
ax.grid()
ax.legend()
# plt.savefig('../../01_Documentos/02_preprocessed/mae.png')
#ax.set_ylim(0,800)
#ax2.set_ylim(0,90)

# %% [markdown]
# fig, ax=plt.subplots(figsize=(20,10))
# plt.bar(dfsamp.index,height=dfsamp.rmse,width=1)

# %% [markdown]
# # MAE diario promedio de todo el año

# %% [markdown]
# ## Se agrupan los promedios de todos los días del año a la misma hora del día (dfmingroup)

# %%
dfrad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 52560 entries, 2019-01-01 00:00:00 to 2019-12-31 23:50:00
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Direct       52473 non-null  float64
#  1   Global       52473 non-null  float64
#  2   Difusa       52473 non-null  float64
#  3   Temperatura  52372 non-null  float64
#  4   Humedad      52372 non-null  float64
#  5   Presion      52372 non-null  float64
#  6   alturasolar  52560 non-null  float64
#  7   azimuth      52560 non-null  float64
#  8   prediccion   52560 non-null  float64
#  9   minutodia    52560 non-null  int64
#  10  me           52473 non-null  float64
#  11  mae          52473 non-null  float64
# dtypes: float64(11), int64(1)
# memory usage: 7.2 MB

# %%
#dfrad.groupby(dfrad.index.to_period('T'))
dfmingroup=dfrad.groupby(['minutodia',pd.Grouper(freq='1H')]).mean()
dfmindia=dfmingroup.groupby(pd.Grouper(level='minutodia',axis=0)).mean()
dfmingroup#['Global','prediccion','mae']
# Out:
#                                Direct  Global  Difusa  Temperatura  Humedad  \
# minutodia tiempo
# 0         2019-01-01 00:00:00     0.0     0.0     0.0        17.85    59.02
#           2019-01-02 00:00:00     0.0     0.0     0.0        18.64    40.69
#           2019-01-03 00:00:00     0.0     0.0     0.0        16.55    48.22
#           2019-01-04 00:00:00     0.0     0.0     0.0        17.82    54.80
#           2019-01-05 00:00:00     0.0     0.0     0.0        19.38    52.38
# ...                               ...     ...     ...          ...      ...
# 1430      2019-12-27 23:00:00     0.0     0.0     0.0        18.96    62.57
#           2019-12-28 23:00:00     0.0     0.0     0.0        17.97    67.71
#           2019-12-29 23:00:00     0.0     0.0     0.0        19.13    56.23
#           2019-12-30 23:00:00     0.0     0.0     0.0        19.25    62.02
#           2019-12-31 23:00:00     0.0     0.0     0.0        21.31    58.82
#
# ...

# %% [markdown]
# ## Se hace un promedio de estos valores (dfmindia)

# %%
dfmindia
# Out:
#            Direct  Global  Difusa  Temperatura    Humedad     Presion  \
# minutodia
# 0             0.0     0.0     0.0    21.615918  61.952466  876.815635
# 10            0.0     0.0     0.0    21.513819  62.155192  876.817880
# 20            0.0     0.0     0.0    21.415055  62.461978  876.822054
# 30            0.0     0.0     0.0    21.335330  62.816648  876.832298
# 40            0.0     0.0     0.0    21.225220  63.101374  876.823931
# ...           ...     ...     ...          ...        ...         ...
# 1390          0.0     0.0     0.0    22.141708  60.417052  876.692448
# 1400          0.0     0.0     0.0    22.041488  60.652727  876.721712
# 1410          0.0     0.0     0.0    21.947769  60.851680  876.755964
# 1420          0.0     0.0     0.0    21.856391  61.108843  876.781824
# 1430          0.0     0.0     0.0    21.745179  61.413994  876.805697
#
#            alturasolar     azimuth  prediccion   me  mae
# minutodia
# ...

# %% [markdown]
# ## Se puede construir así un día característico a lo largo del día

# %%
meanaltura=dfmindia.alturasolar.mean()
fig, ax= plt.subplots(figsize=(20,10))
dfmindia.loc[dfmindia.alturasolar<0,'mae']=np.nan
meandiay=dfmindia.mae.mean()
ax.plot(dfmindia.mae,'b-')
# ax.plot(dfmindia.me)
# ax.plot(dfmindia.alturasolar,'r.')
plt.grid()
print('diferencia absoluta [w/m2] promedio anual por hora:',meandiay) 
#Poner un error porcentual en cada medición de todo el día de todo el año
#Quitar ceros en la noche
# Out:
# diferencia absoluta [w/m2] promedio anual por hora: 82.82415874210439

# %%
fig, ax= plt.subplots(figsize=(19,10))
dfted=dfrad.mae.groupby(by=[dfrad.index.strftime('%H:%M')]).agg(['mean','std','max','min'])
ax.plot(dfted['mean'])
ax.fill_between(dfted.index,dfted['mean']+dfted['std'],dfted['mean']-dfted['std'],color='orange', alpha=0.4)
ax.plot(dfted['max'],'r.')
ax.plot(dfted['min'],'b.')
ax.grid()
plt.ylim(0,900)
# Out:
# (0.0, 900.0)

# %% [markdown]
# ### De donde se pueden eliminar los valores donde en promedio el sol está debajo del horizonte

# %%
meanaltura=dfmindia.alturasolar.mean()
meandiay=dfmindia.mae.mean()
dfmindia.loc[dfmindia.alturasolar<0,'mae']=np.nan
meandiay=dfmindia.mae.mean()

fig, ax= plt.subplots(figsize=(20,10))
ax.plot(dfmindia.mae,'b-')
ax.plot(dfmindia.alturasolar,'r.')
plt.grid()
print('diferencia absoluta [w/m2] promedio anual por hora:',meandiay) 
plt.ylim(0,1000)
#Poner un error porcentual en cada medición de todo el día de todo el año
#Quitar ceros en la noche
# Out:
# diferencia absoluta [w/m2] promedio anual por hora: 104.3448500887001
# (0.0, 1000.0)

# %% [markdown]
# # Porcentaje promedio diario anual[Wh]

# %% [markdown]
# ## Se hace un resample por día, con una suma (dfsamp4)

# %% [markdown]
# ### Después de dividir entre 6 a MAE y a Global obtenemos:

# %% [markdown]
# #### - el error expresado en wh (dif_energia_wh)

# %% [markdown]
# #### -  la radiación diaria   (energia_wh)

# %% [markdown]
# ### Estos dos valores se dividen para sacar el porcentaje (porcentaje_error)

# %% [markdown]
# ### Se hace un promedio anual de todos estos valores diarios (dfsamp5)

# %% [markdown]
# dfsamp4=dfrad.resample('D').sum()
# dfsamp3=dfrad.resample('D').mean()
# #dfsamp3['rmse']=dfsamp3['mse']**.5
# dfsamp3['dif_energia_wh']=dfsamp4['mae']/6
# dfsamp3['energia_wh/m2']=dfsamp4['Global']/6
# dfsamp3['porcentaje_error']=(dfsamp3['dif_energia_wh']/dfsamp3['energia_wh/m2'])*100
#
# #dfsamp3=pd.concat(dfsamp,dfsamp.energia)
# tablita=['Global','prediccion','mae','energia_wh/m2','dif_energia_wh','porcentaje_error','mae_de_día_promedio']
# #dfsamp3.resample('M').mean()
# dfsamp5=dfsamp3.resample('Y').mean()
# dfsamp5['mae_de_día_promedio']=meandiay
# #dfsamp5['porcentaje']=dfsamp3['dif_energia_wh']/dfsamp3['energia_wh']
# #tablita=['Global','prediccion','mae','energia_wh','porcentaje']
# dfsamp5[tablita]
# #calplot.calplot(dfsamp3.porcentaje_error,cmap='jet',vmax=100)
# #energia predicha, NO ocupar diferencias absolutas cuando son wh , solo mae de dia promedio se queda absoluto

# %% [markdown]
# dfsamp4=dfrad.resample('D').sum()
# dfsamp3=dfrad.resample('D').mean()
# #dfsamp3['rmse']=dfsamp3['mse']**.5
# dfsamp3['dif_energia_wh']=dfsamp4['me']/6
# # dfsamp3['dif_energia_wh']=dfsamp4['mae']/6
# dfsamp3['energia_wh/m2']=dfsamp4['Global']/6
# dfsamp3['energia_predicha_wh/m2']=dfsamp4['prediccion']/6
# dfsamp3['porcentaje_error']=(dfsamp3['dif_energia_wh']/dfsamp3['energia_wh/m2'])*100
#
# tablita=['Global','prediccion','energia_wh/m2','energia_predicha_wh/m2','dif_energia_wh','porcentaje_error','mae_de_día_promedio']
# #dfsamp3.resample('M').mean()
# dfsamp5=dfsamp3.resample('Y').mean()
# dfsamp5['mae_de_día_promedio']=meandiay
# dfsamp5[tablita]
# #calplot.calplot(dfsamp3.porcentaje_error,cmap='jet',vmax=100)
# #energia predicha, NO ocupar diferencias absolutas cuando son wh , solo mae de dia promedio se queda absoluto
# #falta porcentaje de mae el que me salía de 20% Hint:"solo descomentando la linea de # dfsamp3['dif_energia_wh']=dfsamp4['mae']/6 "
# #Corregir métricas: Hacer la resta después de haber hecho el promedio anual
# #Hacer double check de métricas: Sacar la energía total anual, hacer resta y hacer porcentaje (debería salir lo mismo)

# %% [markdown]
# # Correcciones aparentes

# %%
dfsamp4=dfrad.resample('D').sum()
dfsamp3=dfrad.resample('D').mean()
#dfsamp3['rmse']=dfsamp3['mse']**.5
dfsamp3['dif_energia_wh']=dfsamp4['me']/6
dfsamp3['dif_energia_wh_mae']=dfsamp4['mae']/6
dfsamp3['energia_wh/m2']=dfsamp4['Global']/6
dfsamp3['porcentaje_mae']=(dfsamp3['dif_energia_wh_mae']/dfsamp3['energia_wh/m2'])*100
dfsamp3['energia_predicha_wh/m2']=dfsamp4['prediccion']/6

#dfsamp3=pd.concat(dfsamp,dfsamp.energia)
tablita=['Global','prediccion','energia_wh/m2','energia_predicha_wh/m2','dif_energia_wh','porcentaje_energia','porcentaje_mae','mae_de_día_promedio']
#dfsamp3.resample('M').mean()
dfsamp5=dfsamp3.resample('Y').mean()
dfsamp5['mae_de_día_promedio']=meandiay
dfsamp5['dif_energia_wh']=-dfsamp5['energia_wh/m2']+dfsamp5['energia_predicha_wh/m2']
dfsamp5['porcentaje_energia']=dfsamp5['dif_energia_wh']/dfsamp5['energia_wh/m2']*100
#dfsamp5['porcentaje']=dfsamp3['dif_energia_wh']/dfsamp3['energia_wh']
#tablita=['Global','prediccion','mae','energia_wh','porcentaje']
dfsamp5[tablita]
#calplot.calplot(dfsamp3.porcentaje_error,cmap='jet',vmax=100)
#energia predicha, NO ocupar diferencias absolutas cuando son wh , solo mae de dia promedio se queda absoluto
# Out:
#                 Global  prediccion  energia_wh/m2  energia_predicha_wh/m2  \
# tiempo
# 2019-12-31  257.683907  233.520633    6181.946408             5604.495184
#
#             dif_energia_wh  porcentaje_energia  porcentaje_mae  \
# tiempo
# 2019-12-31     -577.451223           -9.340929       21.117827
#
#             mae_de_día_promedio
# tiempo
# 2019-12-31            104.34485

# %%
dfsamp3
# Out:
#                 Direct      Global     Difusa  Temperatura    Humedad  \
# tiempo
# 2019-01-01  297.118354  214.334250  37.974319    20.861181  43.491319
# 2019-01-02  136.729479  155.525549  73.540736    19.506250  45.525833
# 2019-01-03  128.959403  162.487715  77.072764    19.352222  47.345833
# 2019-01-04  277.181007  211.670236  36.463153    20.867778  48.588819
# 2019-01-05  251.595938  203.151243  45.259771    21.764444  46.193542
# ...                ...         ...        ...          ...        ...
# 2019-12-27  267.241236  176.810375  36.536319    22.032986  50.249514
# 2019-12-28  189.966458  171.947007  64.202549    21.721389  55.671250
# 2019-12-29  118.546653  144.109007  73.645299    21.129861  53.963403
# 2019-12-30  317.457771  179.595556  23.872979    22.058819  50.667639
# 2019-12-31  312.197993  178.987799  24.581049    22.426875  51.805903
#
#                Presion  alturasolar   azimuth  prediccion  minutodia  \
# tiempo
# ...

# %%
import calplot
calplot.calplot(dfsamp3['dif_energia_wh'],cmap='jet') #hacerlo en porcentual
# Out:
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.
# (<Figure size 900x122.4 with 2 Axes>,
#  array([<AxesSubplot:ylabel='2019'>], dtype=object))

# %%
nombres1=['tiempo','Direct','Global','Difusa','Temperatura','Humedad','Presion','alturasolar','azimuth']#['tiempo','Direct','Global','Difusa','Temperatura','Humedad','Presion','alturasolar','declinacion']
esoru=tst.importa('../../01_Documentos/02_preprocessed/ESORU_noche_angulossolares.csv',nombres1)
tmy=tst.importa('../../01_Documentos/02_preprocessed/TMY_noche_angulossolares.csv',nombres1)
path='../01_Documentos/05_hypopt/'
listmodels=['out_s_144_5_CNN_5_Max_5_LSTM_3_dense_lr_0.0001_in_s_144Global_azimuthaltura.h5'
           ,'out_s_144_5_CNN_5_Max_5_LSTM_3_dense_lr_0.0001_in_s_288Global_azimuthaltura.h5']
# listmodels=['out_s_144_5_CNN_5_Max_5_LSTM_3_dense_lr_0.0001_in_s_144Global_azimuthaltura.h5','out_s_144_5_CNN_5_Max_5_LSTM_3_dense_lr_0.0001_in_s_288Global_azimuthaltura.h5','out_s_144_5_CNN_5_Max_5_LSTM_3_dense_lr_0.0001_in_s_576Global_azimuthaltura.h5']
in_size_list=[144,288,576]
for heo in range(len(listmodels)):
    model5=tst.load_model(path+listmodels[heo])
    in_size,out_size= 576,144 #model4
    #in_size, out_size =72,18 #model3
    dias_rango=360#350#=time_hor
    istep=0#49400-288#6400 
    #x_array,y_array=pre_process(fecha1,fecha2,434,144,esoru)
    scaler3=load(open('../../01_Documentos/03_Models/y_scalerv04.pkl','rb'))
    scaler4=load(open('../../01_Documentos/03_Models/x_scalerv04.pkl','rb'))
    fecha1='01/01/2019'#'01/10/2019'
    fecha2='31/12/2019'#'31/12/2019'
    rango=out_size*int((dias_rango*144)/out_size)
    inputs=['Global','Direct','Temperatura','Humedad','azimuth','alturasolar']
    predi4,targ4=tst.Multioneshot(fecha1,fecha2,esoru,rango,out_size,in_size,istep,model5,inputs,scaler2=scaler3,scaler=scaler4,prep=1)
    mse,rmse,mae=tst.metrics(predi4,targ4,rango)
    nombres=['tiempo','Direct','Global','Difusa','Temperatura','Humedad','Presion','alturasolar','azimuth']
    impesoru=tst.exporta('../../01_Documentos/02_preprocessed/ESORU_noche_angulossolares.csv',predi4,istep,in_size,rango,nombres,sol_data_correction=True)
    impesoru_target=tst.importa('../../01_Documentos/02_preprocessed/ESORU_noche_angulossolares.csv',nombres)
    dfrad=impesoru_target.copy()
    dfrad['prediccion']=impesoru.Global
    dfrad['minutodia']=(dfrad.index.hour*60)+dfrad.index.minute
    dfrad['mse']=(dfrad.Global-dfrad.prediccion)**2
    dfrad['mae']=np.abs(dfrad.Global-dfrad.prediccion)
    dfmingroup=dfrad.groupby(['minutodia',pd.Grouper(freq='1H')]).mean()
    dfmindia=dfmingroup.groupby(pd.Grouper(level='minutodia',axis=0)).mean()
    dfmindia.loc[dfmindia.alturasolar<0,'mae']=np.nan
    meandiay=dfmindia.mae.mean()
    dfsamp4=dfrad.resample('D').sum()
    dfsamp3=dfrad.resample('D').mean()
    #dfsamp3['rmse']=dfsamp3['mse']**.5
    dfsamp3['dif_energia_wh']=dfsamp4['mae']/6
    dfsamp3['energia_wh']=dfsamp4['Global']/6
    dfsamp3['porcentaje_error']=(dfsamp3['dif_energia_wh']/dfsamp3['energia_wh'])*100
    #dfsamp3=pd.concat(dfsamp,dfsamp.energia)
    tablita=['dif_energia_wh','porcentaje_error','mae_de_día_promedio']
    #dfsamp3.resample('M').mean()
    dfsamp5=dfsamp3.resample('Y').mean()
    dfsamp5['mae_de_día_promedio']=meandiay
    print('in_size:',in_size)
    print('model:',listmodels[heo])
    print(dfsamp5[tablita])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-f364bfcf6800> in <module>
#      24     rango=out_size*int((dias_rango*144)/out_size)
#      25     inputs=['Global','Direct','Temperatura','Humedad','azimuth','alturasolar']
# ---> 26     predi4,targ4=tst.Multioneshot(fecha1,fecha2,esoru,rango,out_size,in_size,istep,model5,inputs,scaler2=scaler3,scaler=scaler4,prep=1)
#      27     mse,rmse,mae=tst.metrics(predi4,targ4,rango)
#      28     nombres=['tiempo','Direct','Global','Difusa','Temperatura','Humedad','Presion','alturasolar','azimuth']
#
# ~/aigz/02_Programs/Only_testing_models/testing_2.py in Multioneshot(fecha1, fecha2, esoru, rango, out_size, in_size, istep, model, inputs, scaler, scaler2, prep)
#     256         target=scaler2.inverse_transform(target)
#     257         #pr=model3.predict(x_array[x:x+out_size])[:, :, np.newaxis]
# ...

# %% [markdown]
# # Ciclo para hacer métricas (Actualizada)

# %%
year,month,hour=tst.dfmetricas(impesoru,impesoru_target,listmodels[0])
year
# Out:
#                                                         model  dif_energia_wh  \
# tiempo
# 2019-12-31  out_s_144_lr_0.01_in_s_288Global_azimuthaltura...    -3049.113653
#
#             porcentaje_energia  porcentaje_mae  mae_de_día_promedio
# tiempo
# 2019-12-31          -49.322874       63.075712           323.710408

# %%
nombres1=['tiempo','Direct','Global','Difusa','Temperatura','Humedad','Presion','alturasolar','azimuth']#['tiempo','Direct','Global','Difusa','Temperatura','Humedad','Presion','alturasolar','declinacion']
tablita=['model','dif_energia_wh','porcentaje_energia','porcentaje_mae','mae_de_día_promedio']
pathtab='../../02_Programs/01_Documentos/05_hypopt/'
nombre_archivotab='metricas_288_x.csv'
esoru=tst.importa('../../01_Documentos/02_preprocessed/ESORU_noche_angulossolares_2.csv',nombres1)
tmy=tst.importa('../../01_Documentos/02_preprocessed/TMY_noche_angulossolares.csv',nombres1)
path='../../01_Documentos/04_nohupmodels/'
listmodels=['out_s_144_5_CNN_5_Max_5_LSTM_3_dense_lr_0.0001_in_s_288Global_azimuthaltura.h5']
in_size,out_size= 288,144 #model4
#in_size, out_size =72,18 #model3
dias_rango=360#350#=time_hor
istep=0#49400-288#6400 
#x_array,y_array=pre_process(fecha1,fecha2,434,144,esoru)
scaler3=load(open('../../01_Documentos/03_Models/y_scalerv04.pkl','rb'))
scaler4=load(open('../../01_Documentos/03_Models/x_scalerv04.pkl','rb'))
fecha1='01/01/2019'#'01/10/2019'
fecha2='31/12/2019'#'31/12/2019'
rango=out_size*int((dias_rango*144)/out_size)
inputs=['Global','Direct','Temperatura','Humedad','azimuth','alturasolar']

for heo in range(len(listmodels)):
    model5=tst.load_model(path+listmodels[heo])
    predi4,targ4=tst.Multioneshot(fecha1,fecha2,esoru,rango,out_size,in_size,istep,model5,inputs,scaler2=scaler3,scaler=scaler4,prep=1)
    nombres=['tiempo','Direct','Global','Difusa','Temperatura','Humedad','Presion','alturasolar','azimuth']
    impesoru=tst.exporta('../../01_Documentos/02_preprocessed/ESORU_noche_angulossolares.csv',predi4,istep,in_size,rango,nombres,sol_data_correction=True)
    impesoru_target=tst.importa('../../01_Documentos/02_preprocessed/ESORU_noche_angulossolares.csv',nombres)
    yearly,daily,hourly=tst.dfmetricas(impesoru,impesoru_target,listmodels[heo])
    if heo==0:
        tst.begin_table(yearly,tablita,pathtab,nombre_archivotab)
    if heo>0:
        met=tst.actualizar_bitacora(yearly,tablita,pathtab,nombre_archivotab)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
#esta es para inicializar la tabla
# fecha=datetime.today().strftime('%Y-%m-%d %H:%M')
# cols_gen=['fecha_corrida','origen_libreta','Nombre_modelo','inputs','Output','scaler','learning_rate','épocas','optimizador','callbacks','train_'+metricas[0],'train_'+metricas[1],'train_'+metricas[2],'val_'+metricas[0],'val_'+metricas[1],'val_'+metricas[2],'test_'+metricas[0],'test_'+metricas[1],'test_'+metricas[2],'Cambios','notas'] 
# info=[[fecha, libreta,
#       name_model,inputs,output,str(scaler),lr,epoc,opt,cb,
#       trainloss[0],trainloss[1],trainloss[2],valloss[0],valloss[1],valloss[2],testloss[0],testloss[1],testloss[2],cambios,notas]]

# %%
pathtab='../../02_Programs/01_Documentos/05_hypopt/'
nombre_archivotab='metricas_288_1.csv'
# cols_gen=['modelo','dif_energia_wh','porcentaje_energia','porcentaje_mae','mae_de_día_promedio']
cols_gen=tablita
infodf=year
tst.begin_table(infodf,cols_gen,pathtab,nombre_archivotab)
# Out:
#                                                         model  dif_energia_wh  \
# tiempo
# 2019-12-31  out_s_144_lr_0.01_in_s_288Global_azimuthaltura...    -3049.113653
#
#             porcentaje_energia  porcentaje_mae  mae_de_día_promedio
# tiempo
# 2019-12-31          -49.322874       63.075712           323.710408

# %%
actualizar_bitacora(infodf,cols_gen,path,nombre_archivo)
