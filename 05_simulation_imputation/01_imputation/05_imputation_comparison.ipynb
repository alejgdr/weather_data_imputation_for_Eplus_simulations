# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ann=pd.read_csv('../../01_weather_data/03_imputing_process/02_imputed_data/Tmx_CNN-LSTM_imputed.csv',index_col=0,parse_dates=True)
sarima=pd.read_csv('../../01_weather_data/03_imputing_process/02_imputed_data/Tmx_SARIMA_mae_0_1_1.csv',index_col=0,parse_dates=True)
complete=pd.read_csv('../../01_weather_data/03_imputing_process/01_test_data/base_temixco.csv',index_col=0,parse_dates=True)

# %%
ann['mae']=np.abs(ann.Ig-complete.Ig)
sarima['mae']=np.abs(sarima.Ig-complete.Ig)
ann.head()
# Out:
#                       Ib   Ig     to     RH         P     WS     WD  \
# time
# 2018-01-01 00:00:00  0.0  0.0  18.70  36.34  87864.11  1.422  316.0
# 2018-01-01 00:10:00  0.0  0.0  18.95  35.29  87876.37  1.008  283.7
# 2018-01-01 00:20:00  0.0  0.0  18.94  35.43  87888.64  1.565  326.0
# 2018-01-01 00:30:00  0.0  0.0  18.77  35.89  87887.21  2.175  354.5
# 2018-01-01 00:40:00  0.0  0.0  18.81  36.34  87886.91  1.902  348.0
#
#                      alturasolar     azimuth  mae
# time
# 2018-01-01 00:00:00   -79.806160  166.773196  0.0
# 2018-01-01 00:10:00   -81.878940  170.053742  0.0
# 2018-01-01 00:20:00   -83.764991  173.367191  0.0
# 2018-01-01 00:30:00   -85.236372  176.703016  0.0
# 2018-01-01 00:40:00   -85.827949 -179.949903  0.0

# %%
complete.head()
# Out:
#                         Ib   Ig     To     RH     WS     WD         P   Eg
# time
# 2018-01-01 00:00:00  0.000  0.0  18.70  36.34  1.422  316.0  87864.11  0.0
# 2018-01-01 00:10:00  0.002  0.0  18.95  35.29  1.008  283.7  87876.37  0.0
# 2018-01-01 00:20:00  0.170  0.0  18.94  35.43  1.565  326.0  87888.64  0.0
# 2018-01-01 00:30:00  0.371  0.0  18.77  35.89  2.175  354.5  87887.21  0.0
# 2018-01-01 00:40:00  0.305  0.0  18.81  36.34  1.902  348.0  87886.91  0.0

# %%
dias=['2018-01-12',
 '2018-01-30',
 '2018-04-17',
 '2018-06-15',
 '2018-07-19',
 '2018-08-12',
 '2018-11-14',
 '2018-12-21']

# %%
sarima
# Out:
#                       Ib   Ig     to     RH         P     WS     WD  \
# time
# 2018-01-01 00:00:00  0.0  0.0  18.70  36.34  87864.11  1.422  316.0
# 2018-01-01 00:10:00  0.0  0.0  18.95  35.29  87876.37  1.008  283.7
# 2018-01-01 00:20:00  0.0  0.0  18.94  35.43  87888.64  1.565  326.0
# 2018-01-01 00:30:00  0.0  0.0  18.77  35.89  87887.21  2.175  354.5
# 2018-01-01 00:40:00  0.0  0.0  18.81  36.34  87886.91  1.902  348.0
# ...                  ...  ...    ...    ...       ...    ...    ...
# 2018-12-31 23:10:00  0.0  0.0  18.51  47.29  87484.32  1.715  332.2
# 2018-12-31 23:20:00  0.0  0.0  18.26  48.02  87470.70  1.703  320.5
# 2018-12-31 23:30:00  0.0  0.0  18.39  46.84  87455.03  2.887  335.7
# 2018-12-31 23:40:00  0.0  0.0  17.99  47.85  87470.02  1.528  358.8
# 2018-12-31 23:50:00  0.0  0.0  17.75  49.65  87467.29  0.598  322.3
#
#                      alturasolar     azimuth  mae
# time
# 2018-01-01 00:00:00   -79.806160  166.773196  0.0
# 2018-01-01 00:10:00   -81.878940  170.053742  0.0
# 2018-01-01 00:20:00   -83.764991  173.367191  0.0
# 2018-01-01 00:30:00   -85.236372  176.703016  0.0
# 2018-01-01 00:40:00   -85.827949 -179.949903  0.0
# ...                          ...         ...  ...
# 2018-12-31 23:10:00   -68.725457  151.345160  0.0
# 2018-12-31 23:20:00   -71.001501  154.338568  0.0
# 2018-12-31 23:30:00   -73.264218  157.400817  0.0
# 2018-12-31 23:40:00   -75.506650  160.527038  0.0
# 2018-12-31 23:50:00   -77.716959  163.711070  0.0
#
# [52560 rows x 10 columns]

# %%
ann_mae=ann.mae.resample('D').mean()
sarima_mae=sarima.mae.resample('D').mean()

# %%
ann_maes=[]
sarima_maes=[]
for i in range(len(dias)):
    fig,ax=plt.subplots(figsize=(20,5))
    print('ann_mae:',ann_mae[dias[i]])
    ann_maes.append(ann_mae[dias[i]])
    print('sarima_mae:',sarima_mae[dias[i]])
    sarima_maes.append(sarima_mae[dias[i]])                       
    ax.plot(ann.Ig.loc[dias[i]],'g.-',label='CNN-LSTM_imputed')
    ax.plot(sarima.Ig.loc[dias[i]],'r.-',label='SARIMA_imputed')
    ax.plot(complete.Ig.loc[dias[i]],'k-',label='Measured')
    ax.legend()
    ax.set_ylabel('$I_g[\dfrac{W}{m^2}]$')
    ax.set_xlabel('Date[mm-dd-HH]')
    plt.show()
# Out:
# ann_mae: 5.734092626465689
# sarima_mae: 10.763741228846762
# ann_mae: 70.66917798535029
# sarima_mae: 57.735961897202664
# ann_mae: 14.978851667881012
# sarima_mae: 17.752497086218725
# ann_mae: 152.8260415445434
# sarima_mae: 112.76277897120623
# ann_mae: 17.534537132581075
# sarima_mae: 48.65611964302928
# ann_mae: 144.8527112305959
# sarima_mae: 148.00907175398788
# ann_mae: 167.03413568014568
# sarima_mae: 156.3850152940706
# ann_mae: 5.5701889151467245
# sarima_mae: 17.311225530032065

# %%
dates=pd.DataFrame(dias)
sarima_error=pd.DataFrame(sarima_maes)
ann_error=pd.DataFrame(ann_maes)
ann_error
# Out:
#             0
# 0    5.734093
# 1   70.669178
# 2   14.978852
# 3  152.826042
# 4   17.534537
# 5  144.852711
# 6  167.034136
# 7    5.570189

# %%
errors=pd.concat((dates,sarima_error,ann_error),axis=1,keys=['dates','sarima_mae','ann_mae'])

# %%
errors
# Out:
#         dates  sarima_mae     ann_mae
#             0           0           0
# 0  2018-01-12   10.763741    5.734093
# 1  2018-01-30   57.735962   70.669178
# 2  2018-04-17   17.752497   14.978852
# 3  2018-06-15  112.762779  152.826042
# 4  2018-07-19   48.656120   17.534537
# 5  2018-08-12  148.009072  144.852711
# 6  2018-11-14  156.385015  167.034136
# 7  2018-12-21   17.311226    5.570189
