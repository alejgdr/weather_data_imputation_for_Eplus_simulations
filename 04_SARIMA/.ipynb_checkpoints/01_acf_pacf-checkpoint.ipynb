# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pandas.plotting import register_matplotlib_converters
from statsmodels.tsa.stattools import acf, pacf
import scipy.stats as st

# %%
dfrad=pd.read_csv('../01_weather_data/02_cleaned_data/TMY_night_solar_angles.csv',index_col=0,parse_dates=True)
dfrad['minutodia']=(dfrad.index.hour*60)+dfrad.index.minute
dfrad
# Out:
#                      Direct  Global  Difusa  Temperatura  Humedad   Presion  \
# tiempo
# 2015-01-01 00:00:00     0.0     0.0     0.0        17.75    60.12  878.4097
# 2015-01-01 00:10:00     0.0     0.0     0.0        17.46    59.51  878.8270
# 2015-01-01 00:20:00     0.0     0.0     0.0        17.78    57.60  878.8638
# 2015-01-01 00:30:00     0.0     0.0     0.0        18.08    59.78  878.7399
# 2015-01-01 00:40:00     0.0     0.0     0.0        17.57    59.99  878.6697
# ...                     ...     ...     ...          ...      ...       ...
# 2014-12-31 23:10:00     0.0     0.0     0.0        18.41    58.97  878.8984
# 2014-12-31 23:20:00     0.0     0.0     0.0        19.02    56.31  878.8088
# 2014-12-31 23:30:00     0.0     0.0     0.0        18.66    56.72  878.6418
# 2014-12-31 23:40:00     0.0     0.0     0.0        18.48    56.44  878.4005
# 2014-12-31 23:50:00     0.0     0.0     0.0        18.32    58.76  878.3346
#
#                      alturasolar     azimuth  minutodia
# tiempo
# 2015-01-01 00:00:00   -79.806160  166.773196          0
# 2015-01-01 00:10:00   -81.878940  170.053742         10
# 2015-01-01 00:20:00   -83.764991  173.367191         20
# 2015-01-01 00:30:00   -85.236372  176.703016         30
# 2015-01-01 00:40:00   -85.827949 -179.949903         40
# ...                          ...         ...        ...
# 2014-12-31 23:10:00   -68.725457  151.345160       1390
# 2014-12-31 23:20:00   -71.001501  154.338568       1400
# 2014-12-31 23:30:00   -73.264218  157.400817       1410
# 2014-12-31 23:40:00   -75.506650  160.527038       1420
# 2014-12-31 23:50:00   -77.716959  163.711070       1430
#
# [51570 rows x 9 columns]

# %%
dfmingroup=dfrad.groupby(['minutodia',pd.Grouper(freq='1H')]).mean()
dfmindia=dfmingroup.groupby(pd.Grouper(level='minutodia',axis=0)).mean()
# dfmingroup#['Global','prediccion','mae']

# %%
plt.figure(figsize=(20,10))
data=dfrad.G.loc['2018-01':'2018-1-10'].diff(144)
plt.plot(data,alpha=.5)
plt.plot(data.rolling(144).mean())
plt.plot(data.rolling(144).std())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/7n/c_cvng9j735c5pvm2v5k2tdh0000gp/T/ipykernel_15543/3388036703.py in <module>
#       1 plt.figure(figsize=(20,10))
# ----> 2 data=dfrad.Ig.loc['2018-01':'2018-1-10'].diff(144)
#       3 plt.plot(data,alpha=.5)
#       4 plt.plot(data.rolling(144).mean())
#       5 plt.plot(data.rolling(144).std())
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5476         ):
#    5477             return self[name]
# -> 5478         return object.__getattribute__(self, name)
#    5479
#    5480     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Ig'

# %%
plt.figure(figsize=(20,10))
df_diff=dfmingroup.Ig.loc[600].loc['2018-01':'2018-11'].diff()
plt.plot(df_diff)
plt.plot(df_diff.rolling(30).mean())
plt.plot(df_diff.rolling(30).std())

# %%
data=dfmingroup.Ig.loc[500].loc['2018-01':'2018-11'][2:100].diff()
# st.t.interval(alpha=0.2, df=len(data[2:100])-1, loc=np.mean(data[2:100]), scale=st.sem(data[2:100])) 
st.norm.interval(alpha=0.90, loc=np.mean(data), scale=st.sem(data))
# df_diff[2:100]
np.mean(data)
# Out:
# 1.8680412371134025

# %%
data=dfmingroup.Ig.loc[680].loc['2018-01':'2018-12'].diff()
# tolerance=.99*(np.mean(data)/np.sqrt(len(data)))
tolerance=(1.96/np.sqrt(len(data[145::])))
tolerance
# Out:
# 0.13214317304279544

# %%
fig, ax=plt.subplots(figsize=(20,10))
# ax.plot(pacf(tmx_2018.Ig,nlags=14))
ax.plot(pacf(data[2::],nlags=30),'r.-')
# plt.bar(range(30),pacf(data[2::],nlags=30)[::30])
ax.axhline(y=tolerance,linestyle='--')
ax.axhline(y=-tolerance,linestyle='--')
ax.axhline(y=0,linestyle='-')
# # ax.plot(pacf(tmx_2018.Ig[5:int(144*7)],nlags=144*3))
# # plt.bar(range(lags),pacf(tmx_2018.Ig[5:int(144*7)],nlags=144*4))
# plt.grid()
# ax.set_xlim(0)
# pacf(df_diff,nlags=144)

# %%
lags=30
acf_vals=acf(data[2::],nlags=lags)
fig, ax=plt.subplots(figsize=(20,10))
# # plt.figure(figsize=(20,10))
plt.bar(range(lags),acf_vals[:lags])
ax.axhline(y=tolerance,linestyle='--')
ax.axhline(y=-tolerance,linestyle='--')
ax.axhline(y=0,linestyle='-')
# # ax.set_xlim(144*3)
# # ax.set_ylim(-.15,.15)
ax.grid()
# acf_v
# Out:
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/stattools.py:667: FutureWarning: fft=True will become the default after the release of the 0.12 release of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(

# %%
df_diff.mean()
# Out:
# -4.9733333333333345

# %%
df_diff.std()
# Out:
# 129.23630837461604
