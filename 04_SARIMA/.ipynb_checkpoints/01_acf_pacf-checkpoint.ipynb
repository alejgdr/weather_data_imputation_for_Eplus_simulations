# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pandas.plotting import register_matplotlib_converters
from statsmodels.tsa.stattools import acf, pacf
import scipy.stats as st

# %%
nombres=['time','Ib','Ig','Id','temp','RH','P']
dfrad=pd.read_csv('../01_weather_data/01_raw_data/Temixco_TMY.csv',skiprows=1,names=nombres)
for year in range (2010,2015): #cycle to make the tmy as it was only the year 2015
    dfrad.time=dfrad.time.str.replace(str(year),'2015')

# %%
dfrad.time=pd.to_datetime(dfrad.time)
dfrad=dfrad.set_index(dfrad.time)
dfrad
# Out:
#                                    time     Ib     Ig     Id   temp     RH  \
# time
# 2015-01-01 00:00:00 2015-01-01 00:00:00  0.000  0.000  0.000  17.75  60.12
# 2015-01-01 00:10:00 2015-01-01 00:10:00  0.000  0.000  0.000  17.46  59.51
# 2015-01-01 00:20:00 2015-01-01 00:20:00  0.136  0.000  0.000  17.78  57.60
# 2015-01-01 00:30:00 2015-01-01 00:30:00  0.351  0.000  0.000  18.08  59.78
# 2015-01-01 00:40:00 2015-01-01 00:40:00  0.000  0.002  0.000  17.57  59.99
# ...                                 ...    ...    ...    ...    ...    ...
# 2015-12-31 23:10:00 2015-12-31 23:10:00  0.035  0.028  0.030  18.41  58.97
# 2015-12-31 23:20:00 2015-12-31 23:20:00  0.639  0.102  0.042  19.02  56.31
# 2015-12-31 23:30:00 2015-12-31 23:30:00  0.148  0.000  0.000  18.66  56.72
# 2015-12-31 23:40:00 2015-12-31 23:40:00  0.000  0.000  0.000  18.48  56.44
# 2015-12-31 23:50:00 2015-12-31 23:50:00  0.000  0.000  0.000  18.32  58.76
#
#                             P
# time
# ...

# %%
dfrad['minutodia']=(dfrad.index.hour*60)+dfrad.index.minute
dfrad
# Out:
#                                    time     Ib     Ig     Id   temp     RH  \
# time
# 2015-01-01 00:00:00 2015-01-01 00:00:00  0.000  0.000  0.000  17.75  60.12
# 2015-01-01 00:10:00 2015-01-01 00:10:00  0.000  0.000  0.000  17.46  59.51
# 2015-01-01 00:20:00 2015-01-01 00:20:00  0.136  0.000  0.000  17.78  57.60
# 2015-01-01 00:30:00 2015-01-01 00:30:00  0.351  0.000  0.000  18.08  59.78
# 2015-01-01 00:40:00 2015-01-01 00:40:00  0.000  0.002  0.000  17.57  59.99
# ...                                 ...    ...    ...    ...    ...    ...
# 2015-12-31 23:10:00 2015-12-31 23:10:00  0.035  0.028  0.030  18.41  58.97
# 2015-12-31 23:20:00 2015-12-31 23:20:00  0.639  0.102  0.042  19.02  56.31
# 2015-12-31 23:30:00 2015-12-31 23:30:00  0.148  0.000  0.000  18.66  56.72
# 2015-12-31 23:40:00 2015-12-31 23:40:00  0.000  0.000  0.000  18.48  56.44
# 2015-12-31 23:50:00 2015-12-31 23:50:00  0.000  0.000  0.000  18.32  58.76
#
#                             P  minutodia
# time
# ...

# %%
dfmingroup=dfrad.groupby(['minutodia',pd.Grouper(freq='1H')]).mean()
dfmindia=dfmingroup.groupby(pd.Grouper(level='minutodia',axis=0)).mean()
# dfmingroup#['Global','prediccion','mae']

# %%
plt.figure(figsize=(20,10))
data=dfrad.Ig.loc['2015-01-01':'2015-12-10'].diff(144).diff()
plt.plot(data,alpha=.8)
plt.plot(data.rolling(144).mean())
plt.plot(data.rolling(144).std())

# %%
plt.figure(figsize=(20,10))
df_diff=dfmingroup.Ig.loc[800].loc['2015-01':'2015-12'].diff()
plt.plot(df_diff)
plt.plot(df_diff.rolling(30).mean())
plt.plot(df_diff.rolling(30).std())

# %%
len(data[2::])
# Out:
# 51424

# %%
# data=dfmingroup.Ig.loc[720].loc['2015-01':'2015-12'].diff()
data=dfrad.Ig.loc['2015-1-01':'2015-12-30'].diff(144)
# tolerance=.99*(np.mean(data)/np.sqrt(len(data)))
tolerance=(1.96/np.sqrt(144*7))#len(data)))
lags=144*7
pacf_vals=pacf(data[146:],nlags=lags)
acf_vals=acf(data[146:],nlags=lags)
tolerance
# Out:
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/stattools.py:667: FutureWarning: fft=True will become the default after the release of the 0.12 release of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(
# 0.06173419725817378

# %%
params={'text.latex.preamble':'\\usepackage{lmodern,amsmath}',
       'text.usetex':True,
       'font.size':10,
       'font.family':'lmodern'}
# h_fmt=mdates.DateFormatter('%m-%d-%H')
plt.rcParams.update(params)

# %%
fig, ax=plt.subplots(figsize=(5.63,2.8))
# ax.plot(pacf(tmx_2018.Ig,nlags=14))
ax.plot(pacf_vals,'r.-',linewidth=.2,markersize=.5)
# plt.bar(range(30),pacf(data[2::],nlags=30)[::30])
ax.axhline(y=tolerance,linestyle='--',linewidth=1)
ax.axhline(y=-tolerance,linestyle='--',linewidth=1)
ax.axhline(y=0,linestyle='-',linewidth=.5)
ax.grid(alpha=.3)
# # ax.plot(pacf(tmx_2018.Ig[5:int(144*7)],nlags=144*3))
# # plt.bar(range(lags),pacf(tmx_2018.Ig[5:int(144*7)],nlags=144*4))
# plt.grid()
# ax.set_xlim(0)
# pacf(df_diff,nlags=144)
# ax.grid()
# plt.title('PACF',fontsize=30)
plt.xticks([0,144,288,144*3,144*4,144*5,144*6,144*7])
plt.xlabel('Lags',fontsize=11)
plt.ylabel('PACF',fontsize=11)
plt.tight_layout()
# plt.savefig('../../Tesis_repo/figures/pacf.pdf')

# %%
#30

fig, ax=plt.subplots(figsize=(5.63,2.8)) #2.8
# # plt.figure(figsize=(20,10))
plt.bar(range(lags),acf_vals[:lags])
ax.axhline(y=tolerance,linestyle='--',linewidth=1)
ax.axhline(y=-tolerance,linestyle='--',linewidth=1)
ax.axhline(y=0,linestyle='-',linewidth=.5)
ax.grid(alpha=.3)
# # ax.set_xlim(144*3)
# # ax.set_ylim(-.15,.15)
# ax.grid()
# plt.title('ACF',fontsize=11)
plt.xticks([0,144,288,144*3,144*4,144*5,144*6,144*7])
plt.ylabel('ACF',fontsize=11)
plt.xlabel('Lags',fontsize=11)
plt.tight_layout()
# plt.savefig('../../Tesis_repo/figures/acf.pdf')

# %%
df_diff.mean()
# Out:
# -0.011764705882353706

# %%
df_diff.std()
# Out:
# 215.31505149032557
